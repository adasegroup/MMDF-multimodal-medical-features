# %%
import pandas as pd 
import numpy as np

# %pylab inline
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Feature importance by XGBoost

# %% [markdown]
# Let's see feature importance in accordance to human features (sex, age, diabet, ..)

# %%
from extract_features import feature_importance_by_xgb

# %% [markdown]
# ### Person's feature

# %%
feature_list = ['thyroid_1', 'SBP_1', 'DBP_1', 'AV_1', 'weight', 'height', 'PAD', 'sex', 'age', 'hyp','mass_index', 'heart_failure', 'diabetes', 'MI', 'tromb', 'VD','stroke', 'TIA_1', 'systTR']

# %%
feature_importance_by_xgb(table, feature_list, size_x = 10, size_y = 6)

# %% [markdown]
# ### ECG's feature

# %% [markdown]
# Let's see feature importance in accordance to ECG features.

# %%
feature_list = ['PQ_DUR_GEN', 'P_AXE_GEN', 'PAC', 'area_p_aVF', 'biphase_p_aVF', 'dur_p_aVF', 'idx_p_aVF', 'amp_p_aVF', 'max_dur_p_aVF', 'disp_p_aVF', 'area_p_I', 'idx_p_I','amp_p_I', 'max_dur_p_I', 'disp_p_I', 'area_p_II', 't_till_peak_p_II', 'biphase_p_II', 'dur_p_II', 'idx_p_II', 'amp_p_II', 'max_dur_p_II', 'disp_p_II', 'area_p_III', 'biphase_p_III', 'dur_p_III', 'max_dur_p_III', 'idx_p_III', 'amp_p_III', 'disp_p_III', 'area_p_v1', 'biphase_p_v1', 'max_dur_p_v1', 'idx_p_v1', 'amp_p_v1', 'disp_p_v1', 'ptf_v1', 't_till_peak_p_v1', 'max_dur_aVR', 'max_dur_aVL', 'max_dur_v2', 'max_dur_v3', 'max_dur_v4', 'max_dur_v5', 'max_dur_v6']

# %%
feature_importance_by_xgb(table, feature_list, size_x = 30, size_y = 6)

# %% [markdown]
# ## Outliers

# %%
from plotting import plot_outliers
from extract_features import find_outliers

# %%
import pandas as pd 
import numpy as np

# %pylab inline
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


table = pd.read_csv('/notebook/foundation_of_data_science/multi_modal_data.csv')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/.pyenv/versions/3.7.4/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
list_of_outliers, list_of_labels, list_of_positive, list_of_negative = find_outliers(table, 'max_dur_p_I')
# Out:
# Mean:  139.45209751811993 Std:  37.492297773966555  number_of_objects:  46209  number_of_outliers:  714

# %%
plot_outliers(list_of_positive, list_of_negative, 'max_dur_p_I')
# Out:
# 427
# 287

# %%
list_of_outliers, list_of_labels, list_of_positive, list_of_negative = find_outliers(table, 'mass_index')
# Out:
# Mean:  30.105007341400434 Std:  58.601630021712346  number_of_objects:  46209  number_of_outliers:  13

# %%
plot_outliers(list_of_positive, list_of_negative, 'mass_index')
# Out:
# 11
# 2

# %%
list_of_outliers, list_of_labels, list_of_positive, list_of_negative = find_outliers(table, 'age')
# Out:
# Mean:  62.87723170810881 Std:  12.070373814821156  number_of_objects:  46209  number_of_outliers:  403

# %%
plot_outliers(list_of_positive, list_of_negative, 'age')
# Out:
# 80
# 323
